# %%
import pandas as pd
import matplotlib
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
df_auslaender = pd.read_csv('auslaender_bern.csv')

# %%
df_auslaender.head(10)
# Out:
#    quartier_stadtteil  total_2018  deutschland  mazedonien  spanien  frankreich  italien  eritrea  kosovo  kroatien  oesterreich  polen  portugal  serbien  tuerkei  uk  somalia  usa  china  indien  srilanka  syrien
# 0  Schwarzes Quartier         166           68           0        6           5       23        0       0         0            4      1         1        1        0   3        0    5      0       0         5       0
# 1    Weisses Quartier         141           40           0        7           8       15        0       0         1            4      1         3        2        2   5        0    6      0       0         0       0
# 2     Grünes Quartier         313           94           0        9          27       34        0       0         2            9      6         8        2        5  14        0   14      3       0         1       3
# ...

# %%
df_auslaender.tail(10)
# Out:
#       quartier_stadtteil  total_2018  deutschland  mazedonien  spanien  frankreich  italien  eritrea  kosovo  kroatien  oesterreich  polen  portugal  serbien  tuerkei   uk  somalia  usa  china  indien  srilanka  syrien
# 29             Breitfeld        1281          206          18      116          36      186       22      44        33           21     27        63       50       36    9        1   12     15       9        30       4
# 30           Breitenrain        1384          235          15      101          53      179       45      91        22           28     17        54       16       43   13        5   10     19       8        25       5
# 31              Lorraine         789          169          24       58          14      114       20      34         6           13      8        23        9       19    6       23    5      7       4        41      20
# ...

# %%
df_auslaender.shape
# Out:
# (39, 22)

# %%
df_auslaender.dtypes
# Out:
# quartier_stadtteil    object
# total_2018             int64
# deutschland            int64
# mazedonien             int64
# spanien                int64
# frankreich             int64
# italien                int64
# eritrea                int64
# kosovo                 int64
# kroatien               int64
# oesterreich            int64
# polen                  int64
# portugal               int64
# serbien                int64
# tuerkei                int64
# uk                     int64
# somalia                int64
# usa                    int64
# china                  int64
# indien                 int64
# srilanka               int64
# syrien                 int64
# dtype: object

# %% [markdown]
# ## Analyse Ausländer in Bern

# %% [markdown]
# ### Top 20 Nationalitäten in Bern

# %%
df_auslaender[df_auslaender.quartier_stadtteil == 'stadtbern_total']
# Out:
#    quartier_stadtteil  total_2018  deutschland  mazedonien  spanien  frankreich  italien  eritrea  kosovo  kroatien  oesterreich  polen  portugal  serbien  tuerkei   uk  somalia  usa  china  indien  srilanka  syrien
# 38    stadtbern_total       34375         6345        1238     1970         863     4200      841    1230       471          649    463      1551      737     1182  420      474  371    653     391       812     474

# %% [markdown]
# Für Tabelle Top 20:
# 1. Deutschland: 6345
# 2. Italien: 4200
# 3. Spanien: 1970
# 4. Portugal: 1551
# 5. Mazedonien: 1238
# 6. Kosovo: 1230
# 7. Türkei: 1182
# 8. Frankreich: 863
# 9. Eritrea: 841
# 10. Sri Lanka: 821
# 11. Serbien: 737
# 12. China: 653
# 13. Österreich: 649
# 14. Somalia: 474
# 15. Syrien: 474
# 16. Kroatien: 471
# 17. Polen: 463
# 18. Vereinigtes Königreich: 420
# 19. Indien: 391
# 20. Vereinigte Staaten: 371

# %% [markdown]
# ### 1. Deutsche

# %%
#Beliebteste Quartiere für Deutsche:
#1. Mattenhof-Weissenbühl 1800
#2. Kirchenfeld-Schosshalde 1288
#3. Breitenrain-Lorraine 1038
#4. Länggasse-Felsenau 1032
df_auslaender.sort_values(by='deutschland', ascending=False)
# Out:
#          quartier_stadtteil  total_2018  deutschland  mazedonien  spanien  frankreich  italien  eritrea  kosovo  kroatien  oesterreich  polen  portugal  serbien  tuerkei   uk  somalia  usa  china  indien  srilanka  syrien
# 38          stadtbern_total       34375         6345        1238     1970         863     4200      841    1230       471          649    463      1551      737     1182  420      474  371    653     391       812     474
# 19    Mattenhof-Weissenbühl        7189         1800          73      374         252      812      162     119        82          153    121       215      117      181   98       77   88    168      99       201     101
# 26  Kirchenfeld-Schosshalde        5501         1288          44      240         175      483       63      76        42          119     87       169       89      101  124       41  100    149      96        62      56
# ...

# %%
#Konzentration in Stadtteilen/Quartieren in Prozent:
(100/6345)*1800 #In Mattenhof-Weissenbühl
# Out:
# 28.368794326241133

# %%
(100/6345)*1288 #In Kirchenfeld-Schosshalde
# Out:
# 20.299448384554765

# %%
(100/6345)*1038 #In Breitenrain-Lorraine
# Out:
# 16.35933806146572

# %%
(100/6345)*1032 #In Länggasse-Felsenau
# Out:
# 16.264775413711583

# %% [markdown]
# ### 2. Mazedonier

# %%
# Beliebteste Quartiere für Mazedonier:
#1. Bethlehem 558
#2. Bümpliz  443
df_auslaender.sort_values(by='mazedonien', ascending=False).head(10)
# Out:
#          quartier_stadtteil  total_2018  deutschland  mazedonien  spanien  frankreich  italien  eritrea  kosovo  kroatien  oesterreich  polen  portugal  serbien  tuerkei   uk  somalia  usa  china  indien  srilanka  syrien
# 38          stadtbern_total       34375         6345        1238     1970         863     4200      841    1230       471          649    463      1551      737     1182  420      474  371    653     391       812     474
# 37     Bümpliz-Oberbottigen       12189          934        1018      742          98     1733      398     802       224          128    115       876      382      705   61      309   42    206     110       334     211
# 36                Bethlehem        5757          359         558      319          34      758      167     418        89           51     56       459      202      388   18      166   15     94      56       112     132
# ...

# %%
# Konzentration von Mazedoniern in Stadtteil Bümpliz-Oberbottigen in Prozent:
(100/1238)*1018 # in Bümpliz-Oberbottigen
# Out:
# 82.22940226171244

# %%
(100/1238)* 558 # in Bethlehem
# Out:
# 45.07269789983845

# %%
(100/1238)* 443 # in Bümpliz
# Out:
# 35.78352180936995

# %% [markdown]
# ### 3. Spanier

# %%
# Beliebteste Stadtteile für Spanier:
#1. Bümpliz-Oberbottigen
#2. Mattenhof-Weissenbühl
#3. Breitenrain-Lorraine

# Quartiere
#1. Bümpliz
#2. Bethlehem
#3. Holligen
#4. Breitfeld
#5. Breitenrain

df_auslaender.sort_values(by='spanien', ascending=False).head(10)
# Out:
#          quartier_stadtteil  total_2018  deutschland  mazedonien  spanien  frankreich  italien  eritrea  kosovo  kroatien  oesterreich  polen  portugal  serbien  tuerkei   uk  somalia  usa  china  indien  srilanka  syrien
# 38          stadtbern_total       34375         6345        1238     1970         863     4200      841    1230       471          649    463      1551      737     1182  420      474  371    653     391       812     474
# 37     Bümpliz-Oberbottigen       12189          934        1018      742          98     1733      398     802       224          128    115       876      382      705   61      309   42    206     110       334     211
# 19    Mattenhof-Weissenbühl        7189         1800          73      374         252      812      162     119        82          153    121       215      117      181   98       77   88    168      99       201     101
# ...

# %%
(100/1970)*742 #Bümpliz-Oberbottigen
# Out:
# 37.66497461928934

# %%
(100/1970)*374 #Mattenhof-Weissenbühl
# Out:
# 18.98477157360406

# %%
(100/1970)*373 #Breitenrain-Lorraine
# Out:
# 18.934010152284262

# %% [markdown]
# ### 4. Vereinigtes Königreich

# %%
# Beliebteste Stadtteile für UK:
#1. Kirchenfeld-Schosshalde
#2. Mattenhof-Weissenbühl
#3. Bümpliz-Oberbottigen

# Quartiere
#1. Schosshalde
#2. Bümpliz
#3. Weissenbühl
#4. Innere Stadt
df_auslaender.sort_values(by='uk', ascending=False).head(10)
# Out:
#          quartier_stadtteil  total_2018  deutschland  mazedonien  spanien  frankreich  italien  eritrea  kosovo  kroatien  oesterreich  polen  portugal  serbien  tuerkei   uk  somalia  usa  china  indien  srilanka  syrien
# 38          stadtbern_total       34375         6345        1238     1970         863     4200      841    1230       471          649    463      1551      737     1182  420      474  371    653     391       812     474
# 26  Kirchenfeld-Schosshalde        5501         1288          44      240         175      483       63      76        42          119     87       169       89      101  124       41  100    149      96        62      56
# 19    Mattenhof-Weissenbühl        7189         1800          73      374         252      812      162     119        82          153    121       215      117      181   98       77   88    168      99       201     101
# ...

# %%
(100/420)*124 # In Kirchenfeld-Schosshalde
# Out:
# 29.523809523809522

# %%
(100/420)*98 # In Mattenhof-Weissenbühl
# Out:
# 23.333333333333332

# %%
(100/420)*61 # In Bümpliz-Oberbottigen
# Out:
# 14.523809523809524

# %%
(100/420)*49 # In Schosshalde
# Out:
# 11.666666666666666

# %%
(100/420)*37 # In Bümpliz
# Out:
# 8.809523809523808

# %%
(100/420)*36 # In Weissenbühl
# Out:
# 8.571428571428571

# %% [markdown]
# ### 5. Frankreich

# %%
# Beliebteste Stadtteile für Franzosen:
#1. Mattenhof-Weissenbühl
#2. Kirchenfeld-Schosshalde
#3. Breitenrain-Lorraine
#4. Länggasse-Felsenau

# Quartiere
#1. Monbijou
#2. Schosshalde
#3. Bümpliz
#4. Breitenrain
df_auslaender.sort_values(by='frankreich', ascending=False).head(10)
# Out:
#          quartier_stadtteil  total_2018  deutschland  mazedonien  spanien  frankreich  italien  eritrea  kosovo  kroatien  oesterreich  polen  portugal  serbien  tuerkei   uk  somalia  usa  china  indien  srilanka  syrien
# 38          stadtbern_total       34375         6345        1238     1970         863     4200      841    1230       471          649    463      1551      737     1182  420      474  371    653     391       812     474
# 19    Mattenhof-Weissenbühl        7189         1800          73      374         252      812      162     119        82          153    121       215      117      181   98       77   88    168      99       201     101
# 26  Kirchenfeld-Schosshalde        5501         1288          44      240         175      483       63      76        42          119     87       169       89      101  124       41  100    149      96        62      56
# ...

# %%
#1. Mattenhof-Weissenbühl
(100/863)*252
# Out:
# 29.20046349942063

# %%
#2. Kirchenfeld-Schosshalde
(100/863)*175
# Out:
# 20.278099652375435

# %%
#3. Breitenrain-Lorraine
(100/863)*150
# Out:
# 17.38122827346466

# %%
#4. Länggasse-Felsenau
(100/863)*140
# Out:
# 16.22247972190035

# %%
# Quartiere
#1. Monbijou
(100/863)*65
# Out:
# 7.531865585168019

# %%
#2. Schosshalde
(100/863)*61
# Out:
# 7.068366164542295

# %%
#3. Bümpliz
(100/863)*56
# Out:
# 6.48899188876014

# %% [markdown]
# ### 6. USA

# %%
# Beliebteste Stadtteile für US-Amerikaner:
#1. Kirchenfeld-Schosshalde
#2. Mattenhof-Weissenbühl
#3. Breitenrain-Lorraine

# Quartiere
#1. Innere Stadt
#2. Schosshalde
#3. Spitalacker
df_auslaender.sort_values(by='usa', ascending=False).head(10)
# Out:
#          quartier_stadtteil  total_2018  deutschland  mazedonien  spanien  frankreich  italien  eritrea  kosovo  kroatien  oesterreich  polen  portugal  serbien  tuerkei   uk  somalia  usa  china  indien  srilanka  syrien
# 38          stadtbern_total       34375         6345        1238     1970         863     4200      841    1230       471          649    463      1551      737     1182  420      474  371    653     391       812     474
# 26  Kirchenfeld-Schosshalde        5501         1288          44      240         175      483       63      76        42          119     87       169       89      101  124       41  100    149      96        62      56
# 19    Mattenhof-Weissenbühl        7189         1800          73      374         252      812      162     119        82          153    121       215      117      181   98       77   88    168      99       201     101
# ...

# %%
#1. Kirchenfeld-Schosshalde
(100/371)*100
# Out:
# 26.954177897574123

# %%
#2. Mattenhof-Weissenbühl
(100/371)*88
# Out:
# 23.719676549865227

# %%
#3. Breitenrain-Lorraine
(100/371)*62
# Out:
# 16.711590296495956

# %%
# Quartiere
#1. Innere Stadt
(100/371)*38
# Out:
# 10.242587601078167

# %%
#2. Schosshalde
(100/371)*29
# Out:
# 7.816711590296495

# %%
#3. Spitalacker
(100/371)*24
# Out:
# 6.469002695417789

# %%
100+100
